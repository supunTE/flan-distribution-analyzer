# %%
import os

repo_id = "Open-Orca/FLAN"
subfolders = ["flan_fsnoopt_data", "flan_fsopt_data", "flan_zsnoopt_data", "flan_zsopt_data"]
chose_paraquets_count = [18,42,8,9]
local_base_path = "datasets"

# Select the dataset
dataset_index = 2
dataset_name = subfolders[dataset_index]
selected_count = chose_paraquets_count[dataset_index]

folder_path = os.path.join(local_base_path, dataset_name)
dataset_prefix = dataset_name.split("_")[0]

filtered_datasets_folder = "filtered_datasets"
filtered_folder_path = os.path.join(filtered_datasets_folder, dataset_name)

# %%
# Get hugging face file names

from huggingface_hub import HfApi


api = HfApi()

def get_subfolder_files(repo_id, subfolders):
    repo_files = api.list_repo_files(repo_id, repo_type="dataset")
    return [file for file in repo_files if any(file.startswith(subfolder + "/") for subfolder in subfolders)]

subfolder_files = get_subfolder_files(repo_id, subfolders)
len(subfolder_files), subfolder_files
# Out:
# (721,
#  ['flan_fsnoopt_data/part.0.parquet',
#   'flan_fsnoopt_data/part.1.parquet',
#   'flan_fsnoopt_data/part.10.parquet',
#   'flan_fsnoopt_data/part.100.parquet',
#   'flan_fsnoopt_data/part.101.parquet',
#   'flan_fsnoopt_data/part.102.parquet',
#   'flan_fsnoopt_data/part.103.parquet',
#   'flan_fsnoopt_data/part.104.parquet',
#   'flan_fsnoopt_data/part.105.parquet',
#   'flan_fsnoopt_data/part.106.parquet',
#   'flan_fsnoopt_data/part.107.parquet',
#   'flan_fsnoopt_data/part.108.parquet',
#   'flan_fsnoopt_data/part.109.parquet',
#   'flan_fsnoopt_data/part.11.parquet',
#   'flan_fsnoopt_data/part.110.parquet',
#   'flan_fsnoopt_data/part.111.parquet',
#   'flan_fsnoopt_data/part.112.parquet',
#   'flan_fsnoopt_data/part.113.parquet',
#   'flan_fsnoopt_data/part.114.parquet',
#   'flan_fsnoopt_data/part.115.parquet',
#   'flan_fsnoopt_data/part.116.parquet',
#   'flan_fsnoopt_data/part.117.parquet',
#   'flan_fsnoopt_data/part.118.parquet',
#   'flan_fsnoopt_data/part.119.parquet',
#   'flan_fsnoopt_data/part.12.parquet',
#   'flan_fsnoopt_data/part.120.parquet',
#   'flan_fsnoopt_data/part.121.parquet',
#   'flan_fsnoopt_data/part.122.parquet',
#   'flan_fsnoopt_data/part.123.parquet',
#   'flan_fsnoopt_data/part.124.parquet',
#   'flan_fsnoopt_data/part.125.parquet',
#   'flan_fsnoopt_data/part.126.parquet',
#   'flan_fsnoopt_data/part.127.parquet',
#   'flan_fsnoopt_data/part.128.parquet',
#   'flan_fsnoopt_data/part.129.parquet',
#   'flan_fsnoopt_data/part.13.parquet',
#   'flan_fsnoopt_data/part.130.parquet',
#   'flan_fsnoopt_data/part.131.parquet',
#   'flan_fsnoopt_data/part.132.parquet',
#   'flan_fsnoopt_data/part.133.parquet',
#   'flan_fsnoopt_data/part.134.parquet',
#   'flan_fsnoopt_data/part.135.parquet',
#   'flan_fsnoopt_data/part.136.parquet',
#   'flan_fsnoopt_data/part.137.parquet',
#   'flan_fsnoopt_data/part.138.parquet',
#   'flan_fsnoopt_data/part.139.parquet',
#   'flan_fsnoopt_data/part.14.parquet',
#   'flan_fsnoopt_data/part.140.parquet',
#   'flan_fsnoopt_data/part.141.parquet',
#   'flan_fsnoopt_data/part.142.parquet',
#   'flan_fsnoopt_data/part.143.parquet',
#   'flan_fsnoopt_data/part.144.parquet',
#   'flan_fsnoopt_data/part.145.parquet',
#   'flan_fsnoopt_data/part.146.parquet',
#   'flan_fsnoopt_data/part.147.parquet',
#   'flan_fsnoopt_data/part.148.parquet',
#   'flan_fsnoopt_data/part.149.parquet',
#   'flan_fsnoopt_data/part.15.parquet',
#   'flan_fsnoopt_data/part.150.parquet',
#   'flan_fsnoopt_data/part.151.parquet',
#   'flan_fsnoopt_data/part.152.parquet',
#   'flan_fsnoopt_data/part.153.parquet',
#   'flan_fsnoopt_data/part.154.parquet',
#   'flan_fsnoopt_data/part.155.parquet',
#   'flan_fsnoopt_data/part.156.parquet',
#   'flan_fsnoopt_data/part.157.parquet',
#   'flan_fsnoopt_data/part.158.parquet',
#   'flan_fsnoopt_data/part.159.parquet',
#   'flan_fsnoopt_data/part.16.parquet',
#   'flan_fsnoopt_data/part.160.parquet',
#   'flan_fsnoopt_data/part.161.parquet',
#   'flan_fsnoopt_data/part.162.parquet',
#   'flan_fsnoopt_data/part.163.parquet',
#   'flan_fsnoopt_data/part.164.parquet',
#   'flan_fsnoopt_data/part.17.parquet',
#   'flan_fsnoopt_data/part.18.parquet',
#   'flan_fsnoopt_data/part.19.parquet',
#   'flan_fsnoopt_data/part.2.parquet',
#   'flan_fsnoopt_data/part.20.parquet',
#   'flan_fsnoopt_data/part.21.parquet',
#   'flan_fsnoopt_data/part.22.parquet',
#   'flan_fsnoopt_data/part.23.parquet',
#   'flan_fsnoopt_data/part.24.parquet',
#   'flan_fsnoopt_data/part.25.parquet',
#   'flan_fsnoopt_data/part.26.parquet',
#   'flan_fsnoopt_data/part.27.parquet',
#   'flan_fsnoopt_data/part.28.parquet',
#   'flan_fsnoopt_data/part.29.parquet',
#   'flan_fsnoopt_data/part.3.parquet',
#   'flan_fsnoopt_data/part.30.parquet',
#   'flan_fsnoopt_data/part.31.parquet',
#   'flan_fsnoopt_data/part.32.parquet',
#   'flan_fsnoopt_data/part.33.parquet',
#   'flan_fsnoopt_data/part.34.parquet',
#   'flan_fsnoopt_data/part.35.parquet',
#   'flan_fsnoopt_data/part.36.parquet',
#   'flan_fsnoopt_data/part.37.parquet',
#   'flan_fsnoopt_data/part.38.parquet',
#   'flan_fsnoopt_data/part.39.parquet',
#   'flan_fsnoopt_data/part.4.parquet',
#   'flan_fsnoopt_data/part.40.parquet',
#   'flan_fsnoopt_data/part.41.parquet',
#   'flan_fsnoopt_data/part.42.parquet',
#   'flan_fsnoopt_data/part.43.parquet',
#   'flan_fsnoopt_data/part.44.parquet',
#   'flan_fsnoopt_data/part.45.parquet',
#   'flan_fsnoopt_data/part.46.parquet',
#   'flan_fsnoopt_data/part.47.parquet',
#   'flan_fsnoopt_data/part.48.parquet',
#   'flan_fsnoopt_data/part.49.parquet',
#   'flan_fsnoopt_data/part.5.parquet',
#   'flan_fsnoopt_data/part.50.parquet',
#   'flan_fsnoopt_data/part.51.parquet',
#   'flan_fsnoopt_data/part.52.parquet',
#   'flan_fsnoopt_data/part.53.parquet',
#   'flan_fsnoopt_data/part.54.parquet',
#   'flan_fsnoopt_data/part.55.parquet',
#   'flan_fsnoopt_data/part.56.parquet',
#   'flan_fsnoopt_data/part.57.parquet',
#   'flan_fsnoopt_data/part.58.parquet',
#   'flan_fsnoopt_data/part.59.parquet',
#   'flan_fsnoopt_data/part.6.parquet',
#   'flan_fsnoopt_data/part.60.parquet',
#   'flan_fsnoopt_data/part.61.parquet',
#   'flan_fsnoopt_data/part.62.parquet',
#   'flan_fsnoopt_data/part.63.parquet',
#   'flan_fsnoopt_data/part.64.parquet',
#   'flan_fsnoopt_data/part.65.parquet',
#   'flan_fsnoopt_data/part.66.parquet',
#   'flan_fsnoopt_data/part.67.parquet',
#   'flan_fsnoopt_data/part.68.parquet',
#   'flan_fsnoopt_data/part.69.parquet',
#   'flan_fsnoopt_data/part.7.parquet',
#   'flan_fsnoopt_data/part.70.parquet',
#   'flan_fsnoopt_data/part.71.parquet',
#   'flan_fsnoopt_data/part.72.parquet',
#   'flan_fsnoopt_data/part.73.parquet',
#   'flan_fsnoopt_data/part.74.parquet',
#   'flan_fsnoopt_data/part.75.parquet',
#   'flan_fsnoopt_data/part.76.parquet',
#   'flan_fsnoopt_data/part.77.parquet',
#   'flan_fsnoopt_data/part.78.parquet',
#   'flan_fsnoopt_data/part.79.parquet',
#   'flan_fsnoopt_data/part.8.parquet',
#   'flan_fsnoopt_data/part.80.parquet',
#   'flan_fsnoopt_data/part.81.parquet',
#   'flan_fsnoopt_data/part.82.parquet',
#   'flan_fsnoopt_data/part.83.parquet',
#   'flan_fsnoopt_data/part.84.parquet',
#   'flan_fsnoopt_data/part.85.parquet',
#   'flan_fsnoopt_data/part.86.parquet',
#   'flan_fsnoopt_data/part.87.parquet',
#   'flan_fsnoopt_data/part.88.parquet',
#   'flan_fsnoopt_data/part.89.parquet',
#   'flan_fsnoopt_data/part.9.parquet',
#   'flan_fsnoopt_data/part.90.parquet',
#   'flan_fsnoopt_data/part.91.parquet',
#   'flan_fsnoopt_data/part.92.parquet',
#   'flan_fsnoopt_data/part.93.parquet',
#   'flan_fsnoopt_data/part.94.parquet',
#   'flan_fsnoopt_data/part.95.parquet',
#   'flan_fsnoopt_data/part.96.parquet',
#   'flan_fsnoopt_data/part.97.parquet',
#   'flan_fsnoopt_data/part.98.parquet',
#   'flan_fsnoopt_data/part.99.parquet',
#   'flan_fsopt_data/part.0.parquet',
#   'flan_fsopt_data/part.1.parquet',
#   'flan_fsopt_data/part.10.parquet',
#   'flan_fsopt_data/part.100.parquet',
#   'flan_fsopt_data/part.101.parquet',
#   'flan_fsopt_data/part.102.parquet',
#   'flan_fsopt_data/part.103.parquet',
#   'flan_fsopt_data/part.104.parquet',
#   'flan_fsopt_data/part.105.parquet',
#   'flan_fsopt_data/part.106.parquet',
#   'flan_fsopt_data/part.107.parquet',
#   'flan_fsopt_data/part.108.parquet',
#   'flan_fsopt_data/part.109.parquet',
#   'flan_fsopt_data/part.11.parquet',
#   'flan_fsopt_data/part.110.parquet',
#   'flan_fsopt_data/part.111.parquet',
#   'flan_fsopt_data/part.112.parquet',
#   'flan_fsopt_data/part.113.parquet',
#   'flan_fsopt_data/part.114.parquet',
#   'flan_fsopt_data/part.115.parquet',
#   'flan_fsopt_data/part.116.parquet',
#   'flan_fsopt_data/part.117.parquet',
#   'flan_fsopt_data/part.118.parquet',
#   'flan_fsopt_data/part.119.parquet',
#   'flan_fsopt_data/part.12.parquet',
#   'flan_fsopt_data/part.120.parquet',
#   'flan_fsopt_data/part.121.parquet',
#   'flan_fsopt_data/part.122.parquet',
#   'flan_fsopt_data/part.123.parquet',
#   'flan_fsopt_data/part.124.parquet',
#   'flan_fsopt_data/part.125.parquet',
#   'flan_fsopt_data/part.126.parquet',
#   'flan_fsopt_data/part.127.parquet',
#   'flan_fsopt_data/part.128.parquet',
#   'flan_fsopt_data/part.129.parquet',
#   'flan_fsopt_data/part.13.parquet',
#   'flan_fsopt_data/part.130.parquet',
#   'flan_fsopt_data/part.131.parquet',
#   'flan_fsopt_data/part.132.parquet',
#   'flan_fsopt_data/part.133.parquet',
#   'flan_fsopt_data/part.134.parquet',
#   'flan_fsopt_data/part.135.parquet',
#   'flan_fsopt_data/part.136.parquet',
#   'flan_fsopt_data/part.137.parquet',
#   'flan_fsopt_data/part.138.parquet',
#   'flan_fsopt_data/part.139.parquet',
#   'flan_fsopt_data/part.14.parquet',
#   'flan_fsopt_data/part.140.parquet',
#   'flan_fsopt_data/part.141.parquet',
#   'flan_fsopt_data/part.142.parquet',
#   'flan_fsopt_data/part.143.parquet',
#   'flan_fsopt_data/part.144.parquet',
#   'flan_fsopt_data/part.145.parquet',
#   'flan_fsopt_data/part.146.parquet',
#   'flan_fsopt_data/part.147.parquet',
#   'flan_fsopt_data/part.148.parquet',
#   'flan_fsopt_data/part.149.parquet',
#   'flan_fsopt_data/part.15.parquet',
#   'flan_fsopt_data/part.150.parquet',
#   'flan_fsopt_data/part.151.parquet',
#   'flan_fsopt_data/part.152.parquet',
#   'flan_fsopt_data/part.153.parquet',
#   'flan_fsopt_data/part.154.parquet',
#   'flan_fsopt_data/part.155.parquet',
#   'flan_fsopt_data/part.156.parquet',
#   'flan_fsopt_data/part.157.parquet',
#   'flan_fsopt_data/part.158.parquet',
#   'flan_fsopt_data/part.159.parquet',
#   'flan_fsopt_data/part.16.parquet',
#   'flan_fsopt_data/part.160.parquet',
#   'flan_fsopt_data/part.161.parquet',
#   'flan_fsopt_data/part.162.parquet',
#   'flan_fsopt_data/part.163.parquet',
#   'flan_fsopt_data/part.164.parquet',
#   'flan_fsopt_data/part.165.parquet',
#   'flan_fsopt_data/part.166.parquet',
#   'flan_fsopt_data/part.167.parquet',
#   'flan_fsopt_data/part.168.parquet',
#   'flan_fsopt_data/part.169.parquet',
#   'flan_fsopt_data/part.17.parquet',
#   'flan_fsopt_data/part.170.parquet',
#   'flan_fsopt_data/part.171.parquet',
#   'flan_fsopt_data/part.172.parquet',
#   'flan_fsopt_data/part.173.parquet',
#   'flan_fsopt_data/part.174.parquet',
#   'flan_fsopt_data/part.175.parquet',
#   'flan_fsopt_data/part.176.parquet',
#   'flan_fsopt_data/part.177.parquet',
#   'flan_fsopt_data/part.178.parquet',
#   'flan_fsopt_data/part.179.parquet',
#   'flan_fsopt_data/part.18.parquet',
#   'flan_fsopt_data/part.180.parquet',
#   'flan_fsopt_data/part.181.parquet',
#   'flan_fsopt_data/part.182.parquet',
#   'flan_fsopt_data/part.183.parquet',
#   'flan_fsopt_data/part.184.parquet',
#   'flan_fsopt_data/part.185.parquet',
#   'flan_fsopt_data/part.186.parquet',
#   'flan_fsopt_data/part.187.parquet',
#   'flan_fsopt_data/part.188.parquet',
#   'flan_fsopt_data/part.189.parquet',
#   'flan_fsopt_data/part.19.parquet',
#   'flan_fsopt_data/part.190.parquet',
#   'flan_fsopt_data/part.191.parquet',
#   'flan_fsopt_data/part.192.parquet',
#   'flan_fsopt_data/part.193.parquet',
#   'flan_fsopt_data/part.194.parquet',
#   'flan_fsopt_data/part.195.parquet',
#   'flan_fsopt_data/part.196.parquet',
#   'flan_fsopt_data/part.197.parquet',
#   'flan_fsopt_data/part.198.parquet',
#   'flan_fsopt_data/part.199.parquet',
#   'flan_fsopt_data/part.2.parquet',
#   'flan_fsopt_data/part.20.parquet',
#   'flan_fsopt_data/part.200.parquet',
#   'flan_fsopt_data/part.201.parquet',
#   'flan_fsopt_data/part.202.parquet',
#   'flan_fsopt_data/part.203.parquet',
#   'flan_fsopt_data/part.204.parquet',
#   'flan_fsopt_data/part.205.parquet',
#   'flan_fsopt_data/part.206.parquet',
#   'flan_fsopt_data/part.207.parquet',
#   'flan_fsopt_data/part.208.parquet',
#   'flan_fsopt_data/part.209.parquet',
#   'flan_fsopt_data/part.21.parquet',
#   'flan_fsopt_data/part.210.parquet',
#   'flan_fsopt_data/part.211.parquet',
#   'flan_fsopt_data/part.212.parquet',
#   'flan_fsopt_data/part.213.parquet',
#   'flan_fsopt_data/part.214.parquet',
#   'flan_fsopt_data/part.215.parquet',
#   'flan_fsopt_data/part.216.parquet',
#   'flan_fsopt_data/part.217.parquet',
#   'flan_fsopt_data/part.218.parquet',
#   'flan_fsopt_data/part.219.parquet',
#   'flan_fsopt_data/part.22.parquet',
#   'flan_fsopt_data/part.220.parquet',
#   'flan_fsopt_data/part.221.parquet',
#   'flan_fsopt_data/part.222.parquet',
#   'flan_fsopt_data/part.223.parquet',
#   'flan_fsopt_data/part.224.parquet',
#   'flan_fsopt_data/part.225.parquet',
#   'flan_fsopt_data/part.226.parquet',
#   'flan_fsopt_data/part.227.parquet',
#   'flan_fsopt_data/part.228.parquet',
#   'flan_fsopt_data/part.229.parquet',
#   'flan_fsopt_data/part.23.parquet',
#   'flan_fsopt_data/part.230.parquet',
#   'flan_fsopt_data/part.231.parquet',
#   'flan_fsopt_data/part.232.parquet',
#   'flan_fsopt_data/part.233.parquet',
#   'flan_fsopt_data/part.234.parquet',
#   'flan_fsopt_data/part.235.parquet',
#   'flan_fsopt_data/part.236.parquet',
#   'flan_fsopt_data/part.237.parquet',
#   'flan_fsopt_data/part.238.parquet',
#   'flan_fsopt_data/part.239.parquet',
#   'flan_fsopt_data/part.24.parquet',
#   'flan_fsopt_data/part.240.parquet',
#   'flan_fsopt_data/part.241.parquet',
#   'flan_fsopt_data/part.242.parquet',
#   'flan_fsopt_data/part.243.parquet',
#   'flan_fsopt_data/part.244.parquet',
#   'flan_fsopt_data/part.245.parquet',
#   'flan_fsopt_data/part.246.parquet',
#   'flan_fsopt_data/part.247.parquet',
#   'flan_fsopt_data/part.248.parquet',
#   'flan_fsopt_data/part.249.parquet',
#   'flan_fsopt_data/part.25.parquet',
#   'flan_fsopt_data/part.250.parquet',
#   'flan_fsopt_data/part.251.parquet',
#   'flan_fsopt_data/part.252.parquet',
#   'flan_fsopt_data/part.253.parquet',
#   'flan_fsopt_data/part.254.parquet',
#   'flan_fsopt_data/part.255.parquet',
#   'flan_fsopt_data/part.256.parquet',
#   'flan_fsopt_data/part.257.parquet',
#   'flan_fsopt_data/part.258.parquet',
#   'flan_fsopt_data/part.259.parquet',
#   'flan_fsopt_data/part.26.parquet',
#   'flan_fsopt_data/part.260.parquet',
#   'flan_fsopt_data/part.261.parquet',
#   'flan_fsopt_data/part.262.parquet',
#   'flan_fsopt_data/part.263.parquet',
#   'flan_fsopt_data/part.264.parquet',
#   'flan_fsopt_data/part.265.parquet',
#   'flan_fsopt_data/part.266.parquet',
#   'flan_fsopt_data/part.267.parquet',
#   'flan_fsopt_data/part.268.parquet',
#   'flan_fsopt_data/part.269.parquet',
#   'flan_fsopt_data/part.27.parquet',
#   'flan_fsopt_data/part.270.parquet',
#   'flan_fsopt_data/part.271.parquet',
#   'flan_fsopt_data/part.272.parquet',
#   'flan_fsopt_data/part.273.parquet',
#   'flan_fsopt_data/part.274.parquet',
#   'flan_fsopt_data/part.275.parquet',
#   'flan_fsopt_data/part.276.parquet',
#   'flan_fsopt_data/part.277.parquet',
#   'flan_fsopt_data/part.278.parquet',
#   'flan_fsopt_data/part.279.parquet',
#   'flan_fsopt_data/part.28.parquet',
#   'flan_fsopt_data/part.280.parquet',
#   'flan_fsopt_data/part.281.parquet',
#   'flan_fsopt_data/part.282.parquet',
#   'flan_fsopt_data/part.283.parquet',
#   'flan_fsopt_data/part.284.parquet',
#   'flan_fsopt_data/part.285.parquet',
#   'flan_fsopt_data/part.286.parquet',
#   'flan_fsopt_data/part.287.parquet',
#   'flan_fsopt_data/part.288.parquet',
#   'flan_fsopt_data/part.289.parquet',
#   'flan_fsopt_data/part.29.parquet',
#   'flan_fsopt_data/part.290.parquet',
#   'flan_fsopt_data/part.291.parquet',
#   'flan_fsopt_data/part.292.parquet',
#   'flan_fsopt_data/part.293.parquet',
#   'flan_fsopt_data/part.294.parquet',
#   'flan_fsopt_data/part.295.parquet',
#   'flan_fsopt_data/part.296.parquet',
#   'flan_fsopt_data/part.297.parquet',
#   'flan_fsopt_data/part.298.parquet',
#   'flan_fsopt_data/part.299.parquet',
#   'flan_fsopt_data/part.3.parquet',
#   'flan_fsopt_data/part.30.parquet',
#   'flan_fsopt_data/part.300.parquet',
#   'flan_fsopt_data/part.301.parquet',
#   'flan_fsopt_data/part.302.parquet',
#   'flan_fsopt_data/part.303.parquet',
#   'flan_fsopt_data/part.304.parquet',
#   'flan_fsopt_data/part.305.parquet',
#   'flan_fsopt_data/part.306.parquet',
#   'flan_fsopt_data/part.307.parquet',
#   'flan_fsopt_data/part.308.parquet',
#   'flan_fsopt_data/part.309.parquet',
#   'flan_fsopt_data/part.31.parquet',
#   'flan_fsopt_data/part.310.parquet',
#   'flan_fsopt_data/part.311.parquet',
#   'flan_fsopt_data/part.312.parquet',
#   'flan_fsopt_data/part.313.parquet',
#   'flan_fsopt_data/part.314.parquet',
#   'flan_fsopt_data/part.315.parquet',
#   'flan_fsopt_data/part.316.parquet',
#   'flan_fsopt_data/part.317.parquet',
#   'flan_fsopt_data/part.318.parquet',
#   'flan_fsopt_data/part.319.parquet',
#   'flan_fsopt_data/part.32.parquet',
#   'flan_fsopt_data/part.320.parquet',
#   'flan_fsopt_data/part.321.parquet',
#   'flan_fsopt_data/part.322.parquet',
#   'flan_fsopt_data/part.323.parquet',
#   'flan_fsopt_data/part.324.parquet',
#   'flan_fsopt_data/part.325.parquet',
#   'flan_fsopt_data/part.326.parquet',
#   'flan_fsopt_data/part.327.parquet',
#   'flan_fsopt_data/part.328.parquet',
#   'flan_fsopt_data/part.329.parquet',
#   'flan_fsopt_data/part.33.parquet',
#   'flan_fsopt_data/part.330.parquet',
#   'flan_fsopt_data/part.331.parquet',
#   'flan_fsopt_data/part.332.parquet',
#   'flan_fsopt_data/part.333.parquet',
#   'flan_fsopt_data/part.334.parquet',
#   'flan_fsopt_data/part.335.parquet',
#   'flan_fsopt_data/part.336.parquet',
#   'flan_fsopt_data/part.337.parquet',
#   'flan_fsopt_data/part.338.parquet',
#   'flan_fsopt_data/part.339.parquet',
#   'flan_fsopt_data/part.34.parquet',
#   'flan_fsopt_data/part.340.parquet',
#   'flan_fsopt_data/part.341.parquet',
#   'flan_fsopt_data/part.342.parquet',
#   'flan_fsopt_data/part.343.parquet',
#   'flan_fsopt_data/part.344.parquet',
#   'flan_fsopt_data/part.345.parquet',
#   'flan_fsopt_data/part.346.parquet',
#   'flan_fsopt_data/part.347.parquet',
#   'flan_fsopt_data/part.348.parquet',
#   'flan_fsopt_data/part.349.parquet',
#   'flan_fsopt_data/part.35.parquet',
#   'flan_fsopt_data/part.350.parquet',
#   'flan_fsopt_data/part.351.parquet',
#   'flan_fsopt_data/part.352.parquet',
#   'flan_fsopt_data/part.353.parquet',
#   'flan_fsopt_data/part.354.parquet',
#   'flan_fsopt_data/part.355.parquet',
#   'flan_fsopt_data/part.356.parquet',
#   'flan_fsopt_data/part.357.parquet',
#   'flan_fsopt_data/part.358.parquet',
#   'flan_fsopt_data/part.359.parquet',
#   'flan_fsopt_data/part.36.parquet',
#   'flan_fsopt_data/part.360.parquet',
#   'flan_fsopt_data/part.361.parquet',
#   'flan_fsopt_data/part.362.parquet',
#   'flan_fsopt_data/part.363.parquet',
#   'flan_fsopt_data/part.364.parquet',
#   'flan_fsopt_data/part.365.parquet',
#   'flan_fsopt_data/part.366.parquet',
#   'flan_fsopt_data/part.367.parquet',
#   'flan_fsopt_data/part.368.parquet',
#   'flan_fsopt_data/part.369.parquet',
#   'flan_fsopt_data/part.37.parquet',
#   'flan_fsopt_data/part.370.parquet',
#   'flan_fsopt_data/part.371.parquet',
#   'flan_fsopt_data/part.372.parquet',
#   'flan_fsopt_data/part.373.parquet',
#   'flan_fsopt_data/part.374.parquet',
#   'flan_fsopt_data/part.375.parquet',
#   'flan_fsopt_data/part.376.parquet',
#   'flan_fsopt_data/part.377.parquet',
#   'flan_fsopt_data/part.378.parquet',
#   'flan_fsopt_data/part.379.parquet',
#   'flan_fsopt_data/part.38.parquet',
#   'flan_fsopt_data/part.380.parquet',
#   'flan_fsopt_data/part.381.parquet',
#   'flan_fsopt_data/part.382.parquet',
#   'flan_fsopt_data/part.383.parquet',
#   'flan_fsopt_data/part.384.parquet',
#   'flan_fsopt_data/part.385.parquet',
#   'flan_fsopt_data/part.386.parquet',
#   'flan_fsopt_data/part.387.parquet',
#   'flan_fsopt_data/part.388.parquet',
#   'flan_fsopt_data/part.389.parquet',
#   'flan_fsopt_data/part.39.parquet',
#   'flan_fsopt_data/part.390.parquet',
#   'flan_fsopt_data/part.391.parquet',
#   'flan_fsopt_data/part.392.parquet',
#   'flan_fsopt_data/part.393.parquet',
#   'flan_fsopt_data/part.394.parquet',
#   'flan_fsopt_data/part.4.parquet',
#   'flan_fsopt_data/part.40.parquet',
#   'flan_fsopt_data/part.41.parquet',
#   'flan_fsopt_data/part.42.parquet',
#   'flan_fsopt_data/part.43.parquet',
#   'flan_fsopt_data/part.44.parquet',
#   'flan_fsopt_data/part.45.parquet',
#   'flan_fsopt_data/part.46.parquet',
#   'flan_fsopt_data/part.47.parquet',
#   'flan_fsopt_data/part.48.parquet',
#   'flan_fsopt_data/part.49.parquet',
#   'flan_fsopt_data/part.5.parquet',
#   'flan_fsopt_data/part.50.parquet',
#   'flan_fsopt_data/part.51.parquet',
#   'flan_fsopt_data/part.52.parquet',
#   'flan_fsopt_data/part.53.parquet',
#   'flan_fsopt_data/part.54.parquet',
#   'flan_fsopt_data/part.55.parquet',
#   'flan_fsopt_data/part.56.parquet',
#   'flan_fsopt_data/part.57.parquet',
#   'flan_fsopt_data/part.58.parquet',
#   'flan_fsopt_data/part.59.parquet',
#   'flan_fsopt_data/part.6.parquet',
#   'flan_fsopt_data/part.60.parquet',
#   'flan_fsopt_data/part.61.parquet',
#   'flan_fsopt_data/part.62.parquet',
#   'flan_fsopt_data/part.63.parquet',
#   'flan_fsopt_data/part.64.parquet',
#   'flan_fsopt_data/part.65.parquet',
#   'flan_fsopt_data/part.66.parquet',
#   'flan_fsopt_data/part.67.parquet',
#   'flan_fsopt_data/part.68.parquet',
#   'flan_fsopt_data/part.69.parquet',
#   'flan_fsopt_data/part.7.parquet',
#   'flan_fsopt_data/part.70.parquet',
#   'flan_fsopt_data/part.71.parquet',
#   'flan_fsopt_data/part.72.parquet',
#   'flan_fsopt_data/part.73.parquet',
#   'flan_fsopt_data/part.74.parquet',
#   'flan_fsopt_data/part.75.parquet',
#   'flan_fsopt_data/part.76.parquet',
#   'flan_fsopt_data/part.77.parquet',
#   'flan_fsopt_data/part.78.parquet',
#   'flan_fsopt_data/part.79.parquet',
#   'flan_fsopt_data/part.8.parquet',
#   'flan_fsopt_data/part.80.parquet',
#   'flan_fsopt_data/part.81.parquet',
#   'flan_fsopt_data/part.82.parquet',
#   'flan_fsopt_data/part.83.parquet',
#   'flan_fsopt_data/part.84.parquet',
#   'flan_fsopt_data/part.85.parquet',
#   'flan_fsopt_data/part.86.parquet',
#   'flan_fsopt_data/part.87.parquet',
#   'flan_fsopt_data/part.88.parquet',
#   'flan_fsopt_data/part.89.parquet',
#   'flan_fsopt_data/part.9.parquet',
#   'flan_fsopt_data/part.90.parquet',
#   'flan_fsopt_data/part.91.parquet',
#   'flan_fsopt_data/part.92.parquet',
#   'flan_fsopt_data/part.93.parquet',
#   'flan_fsopt_data/part.94.parquet',
#   'flan_fsopt_data/part.95.parquet',
#   'flan_fsopt_data/part.96.parquet',
#   'flan_fsopt_data/part.97.parquet',
#   'flan_fsopt_data/part.98.parquet',
#   'flan_fsopt_data/part.99.parquet',
#   'flan_zsnoopt_data/part.0.parquet',
#   'flan_zsnoopt_data/part.1.parquet',
#   'flan_zsnoopt_data/part.10.parquet',
#   'flan_zsnoopt_data/part.11.parquet',
#   'flan_zsnoopt_data/part.12.parquet',
#   'flan_zsnoopt_data/part.13.parquet',
#   'flan_zsnoopt_data/part.14.parquet',
#   'flan_zsnoopt_data/part.15.parquet',
#   'flan_zsnoopt_data/part.16.parquet',
#   'flan_zsnoopt_data/part.17.parquet',
#   'flan_zsnoopt_data/part.18.parquet',
#   'flan_zsnoopt_data/part.19.parquet',
#   'flan_zsnoopt_data/part.2.parquet',
#   'flan_zsnoopt_data/part.20.parquet',
#   'flan_zsnoopt_data/part.21.parquet',
#   'flan_zsnoopt_data/part.22.parquet',
#   'flan_zsnoopt_data/part.23.parquet',
#   'flan_zsnoopt_data/part.24.parquet',
#   'flan_zsnoopt_data/part.25.parquet',
#   'flan_zsnoopt_data/part.26.parquet',
#   'flan_zsnoopt_data/part.27.parquet',
#   'flan_zsnoopt_data/part.28.parquet',
#   'flan_zsnoopt_data/part.29.parquet',
#   'flan_zsnoopt_data/part.3.parquet',
#   'flan_zsnoopt_data/part.30.parquet',
#   'flan_zsnoopt_data/part.31.parquet',
#   'flan_zsnoopt_data/part.32.parquet',
#   'flan_zsnoopt_data/part.33.parquet',
#   'flan_zsnoopt_data/part.34.parquet',
#   'flan_zsnoopt_data/part.35.parquet',
#   'flan_zsnoopt_data/part.36.parquet',
#   'flan_zsnoopt_data/part.37.parquet',
#   'flan_zsnoopt_data/part.38.parquet',
#   'flan_zsnoopt_data/part.39.parquet',
#   'flan_zsnoopt_data/part.4.parquet',
#   'flan_zsnoopt_data/part.40.parquet',
#   'flan_zsnoopt_data/part.41.parquet',
#   'flan_zsnoopt_data/part.42.parquet',
#   'flan_zsnoopt_data/part.43.parquet',
#   'flan_zsnoopt_data/part.44.parquet',
#   'flan_zsnoopt_data/part.45.parquet',
#   'flan_zsnoopt_data/part.46.parquet',
#   'flan_zsnoopt_data/part.47.parquet',
#   'flan_zsnoopt_data/part.48.parquet',
#   'flan_zsnoopt_data/part.49.parquet',
#   'flan_zsnoopt_data/part.5.parquet',
#   'flan_zsnoopt_data/part.50.parquet',
#   'flan_zsnoopt_data/part.51.parquet',
#   'flan_zsnoopt_data/part.52.parquet',
#   'flan_zsnoopt_data/part.53.parquet',
#   'flan_zsnoopt_data/part.54.parquet',
#   'flan_zsnoopt_data/part.55.parquet',
#   'flan_zsnoopt_data/part.56.parquet',
#   'flan_zsnoopt_data/part.57.parquet',
#   'flan_zsnoopt_data/part.58.parquet',
#   'flan_zsnoopt_data/part.59.parquet',
#   'flan_zsnoopt_data/part.6.parquet',
#   'flan_zsnoopt_data/part.60.parquet',
#   'flan_zsnoopt_data/part.61.parquet',
#   'flan_zsnoopt_data/part.62.parquet',
#   'flan_zsnoopt_data/part.63.parquet',
#   'flan_zsnoopt_data/part.64.parquet',
#   'flan_zsnoopt_data/part.65.parquet',
#   'flan_zsnoopt_data/part.66.parquet',
#   'flan_zsnoopt_data/part.67.parquet',
#   'flan_zsnoopt_data/part.68.parquet',
#   'flan_zsnoopt_data/part.69.parquet',
#   'flan_zsnoopt_data/part.7.parquet',
#   'flan_zsnoopt_data/part.70.parquet',
#   'flan_zsnoopt_data/part.71.parquet',
#   'flan_zsnoopt_data/part.72.parquet',
#   'flan_zsnoopt_data/part.73.parquet',
#   'flan_zsnoopt_data/part.74.parquet',
#   'flan_zsnoopt_data/part.75.parquet',
#   'flan_zsnoopt_data/part.76.parquet',
#   'flan_zsnoopt_data/part.77.parquet',
#   'flan_zsnoopt_data/part.8.parquet',
#   'flan_zsnoopt_data/part.9.parquet',
#   'flan_zsopt_data/part.0.parquet',
#   'flan_zsopt_data/part.1.parquet',
#   'flan_zsopt_data/part.10.parquet',
#   'flan_zsopt_data/part.11.parquet',
#   'flan_zsopt_data/part.12.parquet',
#   'flan_zsopt_data/part.13.parquet',
#   'flan_zsopt_data/part.14.parquet',
#   'flan_zsopt_data/part.15.parquet',
#   'flan_zsopt_data/part.16.parquet',
#   'flan_zsopt_data/part.17.parquet',
#   'flan_zsopt_data/part.18.parquet',
#   'flan_zsopt_data/part.19.parquet',
#   'flan_zsopt_data/part.2.parquet',
#   'flan_zsopt_data/part.20.parquet',
#   'flan_zsopt_data/part.21.parquet',
#   'flan_zsopt_data/part.22.parquet',
#   'flan_zsopt_data/part.23.parquet',
#   'flan_zsopt_data/part.24.parquet',
#   'flan_zsopt_data/part.25.parquet',
#   'flan_zsopt_data/part.26.parquet',
#   'flan_zsopt_data/part.27.parquet',
#   'flan_zsopt_data/part.28.parquet',
#   'flan_zsopt_data/part.29.parquet',
#   'flan_zsopt_data/part.3.parquet',
#   'flan_zsopt_data/part.30.parquet',
#   'flan_zsopt_data/part.31.parquet',
#   'flan_zsopt_data/part.32.parquet',
#   'flan_zsopt_data/part.33.parquet',
#   'flan_zsopt_data/part.34.parquet',
#   'flan_zsopt_data/part.35.parquet',
#   'flan_zsopt_data/part.36.parquet',
#   'flan_zsopt_data/part.37.parquet',
#   'flan_zsopt_data/part.38.parquet',
#   'flan_zsopt_data/part.39.parquet',
#   'flan_zsopt_data/part.4.parquet',
#   'flan_zsopt_data/part.40.parquet',
#   'flan_zsopt_data/part.41.parquet',
#   'flan_zsopt_data/part.42.parquet',
#   'flan_zsopt_data/part.43.parquet',
#   'flan_zsopt_data/part.44.parquet',
#   'flan_zsopt_data/part.45.parquet',
#   'flan_zsopt_data/part.46.parquet',
#   'flan_zsopt_data/part.47.parquet',
#   'flan_zsopt_data/part.48.parquet',
#   'flan_zsopt_data/part.49.parquet',
#   'flan_zsopt_data/part.5.parquet',
#   'flan_zsopt_data/part.50.parquet',
#   'flan_zsopt_data/part.51.parquet',
#   'flan_zsopt_data/part.52.parquet',
#   'flan_zsopt_data/part.53.parquet',
#   'flan_zsopt_data/part.54.parquet',
#   'flan_zsopt_data/part.55.parquet',
#   'flan_zsopt_data/part.56.parquet',
#   'flan_zsopt_data/part.57.parquet',
#   'flan_zsopt_data/part.58.parquet',
#   'flan_zsopt_data/part.59.parquet',
#   'flan_zsopt_data/part.6.parquet',
#   'flan_zsopt_data/part.60.parquet',
#   'flan_zsopt_data/part.61.parquet',
#   'flan_zsopt_data/part.62.parquet',
#   'flan_zsopt_data/part.63.parquet',
#   'flan_zsopt_data/part.64.parquet',
#   'flan_zsopt_data/part.65.parquet',
#   'flan_zsopt_data/part.66.parquet',
#   'flan_zsopt_data/part.67.parquet',
#   'flan_zsopt_data/part.68.parquet',
#   'flan_zsopt_data/part.69.parquet',
#   'flan_zsopt_data/part.7.parquet',
#   'flan_zsopt_data/part.70.parquet',
#   'flan_zsopt_data/part.71.parquet',
#   'flan_zsopt_data/part.72.parquet',
#   'flan_zsopt_data/part.73.parquet',
#   'flan_zsopt_data/part.74.parquet',
#   'flan_zsopt_data/part.75.parquet',
#   'flan_zsopt_data/part.76.parquet',
#   'flan_zsopt_data/part.77.parquet',
#   'flan_zsopt_data/part.78.parquet',
#   'flan_zsopt_data/part.79.parquet',
#   'flan_zsopt_data/part.8.parquet',
#   'flan_zsopt_data/part.80.parquet',
#   'flan_zsopt_data/part.81.parquet',
#   'flan_zsopt_data/part.82.parquet',
#   'flan_zsopt_data/part.9.parquet'])

# %%
# Download paraquet files

import concurrent.futures

def download_file(api, repo_id, file, local_base_path):
    api.hf_hub_download(repo_id=repo_id, repo_type="dataset", 
                                         filename=file, local_dir=local_base_path)

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
        futures = [executor.submit(download_file, api, repo_id, file, local_base_path) 
                   for file in subfolder_files]
        
        concurrent.futures.wait(futures)

# %%
# Check all files are downloaded
def get_parquet_files_by_folder(folder_path):
    items = os.listdir(folder_path)
    return [item for item in items if item.endswith('.parquet') and os.path.isfile(os.path.join(folder_path, item))]

parquet_files = get_parquet_files_by_folder(folder_path)
origin_file_count = len(get_subfolder_files(repo_id, [dataset_name]))
print(f"Total files '{folder_path}': {len(parquet_files)} out of {origin_file_count}")
# Out:
# Total files 'datasets/flan_zsnoopt_data': 78 out of 78

# %%
# Gather filtered tasks
import os
import pandas as pd
import numpy as np

column = "_task_name"

skipping_tasks = [
    "wmt16_translate/cs-en:1.0.0",
    "wmt14_translate/fr-en:1.0.0",
    "wmt16_translate/de-en:1.0.0",
    "wmt16_translate/ru-en:1.0.0",
    "wmt16_translate/fi-en:1.0.0",
    "wmt16_translate/ro-en:1.0.0",
    "wmt16_translate/tr-en:1.0.0",
    "word_segment"
]
    
os.makedirs(filtered_folder_path, exist_ok=True)

# Single File Check
# file = f"part.{0}.parquet"
# print(file)
# file_path = os.path.join(folder_path, file)
# df = pd.read_parquet(file_path)
# fldf = df[~df[column].isin(skipping_tasks)]
# len(df), len(fldf)

for i in range(selected_count):
    file = f"part.{i}.parquet"
    print(file)
    file_path = os.path.join(folder_path, file)
    df = pd.read_parquet(file_path)
    fldf = df[~df[column].isin(skipping_tasks)]

    filtered_file_path= os.path.join(filtered_folder_path, f"{i}.parquet")
    fldf.to_parquet(filtered_file_path)
# Out:
# part.0.parquet
# part.1.parquet
# part.2.parquet
# part.3.parquet
# part.4.parquet
# part.5.parquet
# part.6.parquet
# part.7.parquet

# %%
import pandas as pd

df_list = []

for i in range(selected_count):
    file = f"{i}.parquet"
    file_path = os.path.join(filtered_folder_path, file)
    df = pd.read_parquet(file_path)
    df_list.append(df)

combined_df = pd.concat(df_list, ignore_index=True).reset_index(drop=True)
combined_df
# Out:
#                                                     inputs  \
# 0        Is it possible to conclude that "A little girl...
# 1        Math problem: Solve -24*y - 1654*y = -218*y - ...
# 2        Coyote\n\nThe coyote (Canis latrans); from Nah...
# 3        Solve this math problem\n\nSolve 948 = 205*u -...
# 4                                  Write a positive tweet.
# ...                                                    ...
# 1046387  Write a sentence based on "ukrainian prosecuto...
# 1046388                            Write a positive tweet.
# 1046389  News article: The Mad Men Effect\n\nBetty Drap...
# 1046390  Victor Hugo, who stood among the crowd, dutifu...
# 1046391  Short movie review: inconsistent , dishonest \...
#
#                                                    targets  _template_idx  \
# 0                                                      yes              7
# 1                                                       91              6
# 2                                                       no              8
# 3                                                        9              1
# 4        Making sausage &amp; peppers for dinner. Mmmmm...              8
# ...                                                    ...            ...
# 1046387  ukraine 's top prosecutor 's office said frida...              9
# 1046388  Jonas Brothers! Lines, Vines, And Trying Time!...              8
# 1046389  Best Dressed Show Betty Draper: style icon of ...              6
# 1046390                                                 no              9
# 1046391                                           negative              1
#
#         _task_source                             _task_name _template_type
# 0           Flan2021                             snli:1.1.0       zs_noopt
# 1           Flan2021  math_dataset/algebra__linear_1d:1.0.0       zs_noopt
# 2           Flan2021                           bool_q:1.0.0       zs_noopt
# 3           Flan2021  math_dataset/algebra__linear_1d:1.0.0       zs_noopt
# 4           Flan2021                     sentiment140:1.0.0       zs_noopt
# ...              ...                                    ...            ...
# 1046387     Flan2021                         gigaword:1.2.0       zs_noopt
# 1046388     Flan2021                     sentiment140:1.0.0       zs_noopt
# 1046389     Flan2021                         newsroom:1.0.0       zs_noopt
# 1046390     Flan2021                        glue/mnli:2.0.0       zs_noopt
# 1046391     Flan2021                        glue/sst2:2.0.0       zs_noopt
#
# [1046392 rows x 6 columns]

# %%
# # Push by Chunk

# import pandas as pd
# from datasets import Dataset
# import numpy as np

# # Define a function to upload the dataset in chunks
# def upload_in_chunks(df, chunk_size, repo_id, dataset_name):
#     for i in range(0, len(df), chunk_size):
#         chunk = df.iloc[i:i+chunk_size]
#         dataset = Dataset.from_pandas(chunk)
#         split_name = f"{dataset_name}_chunk_{i//chunk_size}"
#         dataset.push_to_hub(repo_id, config_name=dataset_name, split=split_name)
#         print(f"Uploaded chunk {i//chunk_size}")

# # Define chunk size, repo ID, and dataset name
# number_of_chunks = 8
# chunk_size = int(np.ceil(len(combined_df) / number_of_chunks))
# print(chunk_size)
# repo_id = "0xAIT/flan-subset"

# # Upload the DataFrame in chunks
# upload_in_chunks(combined_df, chunk_size, repo_id, dataset_name)
# Out:
# 450457
# Uploading the dataset shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/226 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:   0%|          | 0/226 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/2.27k [00:00<?, ?B/s]
# Uploaded chunk 0
# Uploading the dataset shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/226 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:   0%|          | 0/226 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/2.82k [00:00<?, ?B/s]
# Uploaded chunk 1
# Uploading the dataset shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/226 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:   0%|          | 0/226 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/3.00k [00:00<?, ?B/s]
# Uploaded chunk 2
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# # Complete Push

# from datasets import Dataset
# import pandas as pd

# subset_repo_id = "0xAIT/flan-subset"
# dataset = Dataset.from_pandas(combined_df)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Upload as a folder

# %%
# import os
# from datasets import Dataset
# import pandas as pd

# subfolders = ["flan_fsnoopt_data", "flan_fsopt_data", "flan_zsnoopt_data", "flan_zsopt_data"]
# chose_paraquets_count = [18,42,8,9]
# dataset_index = 1

# dataset_name = subfolders[dataset_index]
# selected_count = chose_paraquets_count[dataset_index]

# filtered_datasets_folder = "filtered_datasets"
# filtered_folder_path = os.path.join(filtered_datasets_folder, dataset_name)

# subset_repo_id = "0xAIT/flan-subset"

# df_list = []

# for i in range(selected_count):
#     file = f"{i}.parquet"
#     print(file)
#     file_path = os.path.join(filtered_folder_path, file)
#     df = pd.read_parquet(file_path)
#     df_list.append(df)

# combined_df = pd.concat(df_list, ignore_index=True).reset_index(drop=True)
# combined_df
# Out:
# 0.parquet
# 1.parquet
# 2.parquet
# 3.parquet
# 4.parquet
# 5.parquet
# 6.parquet
# 7.parquet
# 8.parquet
# 9.parquet
# 10.parquet
# 11.parquet
# 12.parquet
# 13.parquet
# 14.parquet
# 15.parquet
# 16.parquet
# 17.parquet
# 18.parquet
# 19.parquet
# 20.parquet
# 21.parquet
# 22.parquet
# 23.parquet
# 24.parquet
# 25.parquet
# 26.parquet
# 27.parquet
# 28.parquet
# 29.parquet
# 30.parquet
# 31.parquet
# 32.parquet
# 33.parquet
# 34.parquet
# 35.parquet
# 36.parquet
# 37.parquet
# 38.parquet
# 39.parquet
# 40.parquet
# 41.parquet
#                                                     inputs  \
# 0        Question:\nSummarize this: australia on monday...
# 1        Question:\nSolve -13*s + 4151 = 3982 for s..\n...
# 2        Problem: Wilhelmus Simon Petrus Fortuijn, know...
# 3        Q: What is the solution?\nSolve 23 = 9*m - 13 ...
# 4        Question:\nWrite a tweet that is positive (OPT...
# ...                                                    ...
# 1801822  question: Teacher asked me this: Solve -28*q +...
# 1801823  QUESTION: Math problem: Solve 22*a - 43 = -153...
# 1801824  Concepts: come, engine, station, track\nA: A s...
# 1801825  Question: Write a text based on "india promise...
# 1801826  IN: the nationwide outcry seems to be against ...
#
#                                                    targets  _template_idx  \
# 0        s. africa 's mbeki defends china-africa relations              1
# 1                                                       -2              4
# 2        He appeared as Charley in an Encores! staged c...              4
# 3                                                      -50              8
# 4                --- just got back from State....work at 7              0
# ...                                                    ...            ...
# 1801822                                                 58              5
# 1801823                                                  5              7
# 1801824                       sun breaking through a cloud              3
# 1801825  yugoslavia called monday on the u.n. security ...              8
# 1801826  roc fair trade officials meet australian count...              1
#
#         _task_source                             _task_name _template_type
# 0           Flan2021                         gigaword:1.2.0         fs_opt
# 1           Flan2021  math_dataset/algebra__linear_1d:1.0.0         fs_opt
# 2           Flan2021                             quac:1.0.0         fs_opt
# 3           Flan2021  math_dataset/algebra__linear_1d:1.0.0         fs_opt
# 4           Flan2021                     sentiment140:1.0.0         fs_opt
# ...              ...                                    ...            ...
# 1801822     Flan2021  math_dataset/algebra__linear_1d:1.0.0         fs_opt
# 1801823     Flan2021  math_dataset/algebra__linear_1d:1.0.0         fs_opt
# 1801824     Flan2021                   gem/common_gen:1.1.0         fs_opt
# 1801825     Flan2021                         gigaword:1.2.0         fs_opt
# 1801826     Flan2021                         gigaword:1.2.0         fs_opt
#
# [1801827 rows x 6 columns]

# %%
combined_df
# Out:
#                                                    inputs  \
# 0       input question: Write a random tweet?\n\nA ran...
# 1       Problem: uganda 's main opposition leader is k...
# 2       Solve -167*m + 5725 = 1383 for m.\nSolve this ...
# 3       Premise & hypothesis: Is the premise "Two litt...
# 4       Question: What is the solution?\n\nSolve -65*d...
# ...                                                   ...
# 985404  Problem: Math Problem\nSolve -17*i = -353*i + ...
# 985405  input question: Write a random tweet?\n\nA ran...
# 985406  Problem: the armed basque separatist group eta...
# 985407  mtv announced monday it will move ahead with p...
# 985408  Problem: Write the next sentence for:\nHow to ...
#
#                                                   targets  _template_idx  \
# 0       @xxnissa Well, I truly love her, but someday I...              6
# 1       chinese arctic research highlights global clim...              6
# 2                                                     -34              6
# 3                                                     yes              5
# 4                                                       0              2
# ...                                                   ...            ...
# 985404                                                 -2              3
# 985405  Just booked tickets to go to Brisbane this wee...              6
# 985406      china develops anti-terrorism training system              6
# 985407  candle vigils and beds of flowers as stockholm...              0
# 985408  However, you should still be prepared to spend...              4
#
#        _task_source                             _task_name _template_type
# 0          Flan2021                     sentiment140:1.0.0       fs_noopt
# 1          Flan2021                         gigaword:1.2.0       fs_noopt
# 2          Flan2021  math_dataset/algebra__linear_1d:1.0.0       fs_noopt
# 3          Flan2021                             snli:1.1.0       fs_noopt
# 4          Flan2021  math_dataset/algebra__linear_1d:1.0.0       fs_noopt
# ...             ...                                    ...            ...
# 985404     Flan2021  math_dataset/algebra__linear_1d:1.0.0       fs_noopt
# 985405     Flan2021                     sentiment140:1.0.0       fs_noopt
# 985406     Flan2021                         gigaword:1.2.0       fs_noopt
# 985407     Flan2021                         gigaword:1.2.0       fs_noopt
# 985408     Flan2021                        hellaswag:1.1.0       fs_noopt
#
# [985409 rows x 6 columns]

# %%
dataset_name
# Out:
# 'flan_zsnoopt_data'

# %%
# Chunking the filtered dataset

import numpy as np

output_dir = f"chunks/{dataset_name}"
os.makedirs(output_dir, exist_ok=True)

number_of_chunks = 3
rows_per_chunk = int(np.ceil(len(combined_df) / number_of_chunks))

for i in range(number_of_chunks):
    start = i * rows_per_chunk
    end = min((i + 1) * rows_per_chunk, len(combined_df))
    chunk_df = combined_df.iloc[start:end]
    chunk_df.to_parquet(f"{output_dir}/part.{i}.parquet")

    print(f"Chunk {i}: {len(chunk_df)}")
# Out:
# Chunk 0: 348798
# Chunk 1: 348798
# Chunk 2: 348796

# %%
# chunk_files = [f"part.{i}.parquet" for i in range(number_of_chunks)]

# chunk_path = f"{output_dir}/{chunk_files[0]}"
# chunk_df = pd.read_parquet(chunk_path)
# chunk_df
# Out:
#                                                    inputs  \
# 0       Question:\nSummarize this: australia on monday...
# 1       Question:\nSolve -13*s + 4151 = 3982 for s..\n...
# 2       Problem: Wilhelmus Simon Petrus Fortuijn, know...
# 3       Q: What is the solution?\nSolve 23 = 9*m - 13 ...
# 4       Question:\nWrite a tweet that is positive (OPT...
# ...                                                   ...
# 225224  Text: sudan is ready to send an ambassador to ...
# 225225  Problem: Article: Adrian Brown, of Brockley Ri...
# 225226  Problem: manchester united manager sir alex fe...
# 225227  Question: Write a text based on "compromise se...
# 225228  question: a swedish court has found a german w...
#
#                                                   targets  _template_idx  \
# 0       s. africa 's mbeki defends china-africa relations              1
# 1                                                      -2              4
# 2       He appeared as Charley in an Encores! staged c...              4
# 3                                                     -50              8
# 4               --- just got back from State....work at 7              0
# ...                                                   ...            ...
# 225224      saramago s body taken to portugal for funeral              2
# 225225  [[Northern Ireland boss Michael O'Neill is con...              2
# 225226                      top powers meet iran on nukes              6
# 225227  the task force on it manpower , chaired by sec...              8
# 225228    protests in bethlehem over israeli construction              7
#
#        _task_source                             _task_name _template_type
# 0          Flan2021                         gigaword:1.2.0         fs_opt
# 1          Flan2021  math_dataset/algebra__linear_1d:1.0.0         fs_opt
# 2          Flan2021                             quac:1.0.0         fs_opt
# 3          Flan2021  math_dataset/algebra__linear_1d:1.0.0         fs_opt
# 4          Flan2021                     sentiment140:1.0.0         fs_opt
# ...             ...                                    ...            ...
# 225224     Flan2021                         gigaword:1.2.0         fs_opt
# 225225     Flan2021                       huggingface:xsum         fs_opt
# 225226     Flan2021                         gigaword:1.2.0         fs_opt
# 225227     Flan2021                         gigaword:1.2.0         fs_opt
# 225228     Flan2021                         gigaword:1.2.0         fs_opt
#
# [225229 rows x 6 columns]

# %%
from datasets import Dataset
from huggingface_hub import HfApi
import os

api = HfApi()

subset_repo_id = "0xAIT/flan-subset"
api.upload_folder(folder_path=output_dir, repo_id=subset_repo_id, repo_type="dataset", path_in_repo=dataset_name)
# Out:
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# part.2.parquet:   0%|          | 0.00/187M [00:00<?, ?B/s]
# part.0.parquet:   0%|          | 0.00/189M [00:00<?, ?B/s]
# part.1.parquet:   0%|          | 0.00/188M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/0xAIT/flan-subset/commit/f73a1c129051836f52aa6882aa29037f4746e0a1', commit_message='Upload folder using huggingface_hub', commit_description='', oid='f73a1c129051836f52aa6882aa29037f4746e0a1', pr_url=None, pr_revision=None, pr_num=None)

# %%
# total_rows = 0


# for i in range(5):
#     file = f"{i}.parquet"
#     file_path = os.path.join(filtered_folder_path, file)
#     df = pd.read_parquet(file_path)

#     first_value = df_list[i].iloc[0]
#     real_value = combined_df.iloc[total_rows]
#     total_rows += len(df)
#     assert first_value.equals(real_value)

#     new_df = {
#         "original": first_value["inputs"][:30],
#         "filtered": real_value["inputs"][:30]
#     }
#     print(new_df)
# Out:
# {'original': 'input question: Write a random', 'filtered': 'input question: Write a random'}
# {'original': "Question: i'm always afraid th", 'filtered': "Question: i'm always afraid th"}
# {'original': 'What should I do to concentrat', 'filtered': 'What should I do to concentrat'}
# {'original': 'Solve -132*z - 2310 = 22*z for', 'filtered': 'Solve -132*z - 2310 = 22*z for'}
# {'original': 'Q: Write a negative tweet.\n\nA:', 'filtered': 'Q: Write a negative tweet.\n\nA:'}

# %%
# # Save Tasks Names
# import os
# import pandas as pd
# import numpy as np
# from multiprocessing import Pool, cpu_count

# column = "_task_name"
# subfolder_file_prefix = "part"

# def get_unique_values(file_path):
#     df = pd.read_parquet(file_path)
#     unique_values = df[column].unique()
#     return unique_values.tolist()


# unique_values = []

# for i in range(origin_file_count):
#     file = f"{subfolder_file_prefix}.{i}.parquet"
#     print(file)
#     file_path = os.path.join(folder_path, file)
#     unique_values.extend(get_unique_values(file_path))


# values = list(set(unique_values))

# outputpath = "tasks/t0.txt"
# with open(outputpath, "w") as f:
#     for value in values:
#         f.write(f"{value}\n")
